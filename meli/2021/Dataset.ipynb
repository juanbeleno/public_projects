# %% [markdown]
# # Dataset
#
# In this Notebook, I'll extract some features to try to create an initial dataset for training a good model.

# %%
import pandas as pd

train_data = pd.read_parquet('inputs/train_data.parquet', engine='pyarrow')
train_data.index = train_data.sku
train_data
# Out:
#            sku        date  sold_quantity  current_price currency  \
# sku
# 464801  464801  2021-02-01              0         156.78      REA
# 464801  464801  2021-02-02              0         156.78      REA
# 464801  464801  2021-02-03              0         156.78      REA
# 464801  464801  2021-02-04              0         156.78      REA
# 464801  464801  2021-02-05              1         156.78      REA
# ...        ...         ...            ...            ...      ...
# 129187  129187  2021-03-31              0       22057.00      ARG
# 6707      6707  2021-03-31              0       26999.00      ARG
# 170355  170355  2021-03-31              0        3400.00      ARG
# 246568  246568  2021-03-31              0        6289.00      ARG
# 49718    49718  2021-03-31              0        1990.00      ARG
#
#        listing_type shipping_logistic_type shipping_payment  minutes_active
# sku
# 464801      classic            fulfillment    free_shipping     1440.000000
# 464801      classic            fulfillment    free_shipping     1440.000000
# 464801      classic            fulfillment    free_shipping     1440.000000
# 464801      classic            fulfillment    free_shipping     1440.000000
# 464801      classic            fulfillment    free_shipping     1440.000000
# ...             ...                    ...              ...             ...
# 129187      classic               drop_off    free_shipping      267.710767
# 6707        classic          cross_docking    free_shipping      266.083333
# 170355      classic               drop_off    paid_shipping        0.252633
# 246568      classic            fulfillment    free_shipping      135.416667
# 49718       classic               drop_off    paid_shipping       88.033333
#
# [37660279 rows x 9 columns]

# %% [markdown]
# I'll manually define mappings from categorical variables to numbers.

# %%
currency_map = {
    'REA': 0,
    'MEX': 1,
    'ARG': 2,
    'DOL': 3
}

listing_type_map = {
    'classic': 0,
    'premium': 1
}

shipping_logistic_type_map = {
    'fulfillment': 0,
    'drop_off': 1,
    'cross_docking': 2
}

shipping_payment_map = {
    'paid_shipping': 0,
    'free_shipping': 1
}

# %% [markdown]
# I'll replace the values of the categorical variables with their equivalent in numbers.

# %%
train_data['currency'] = train_data['currency'].map(currency_map)
train_data['listing_type'] = train_data['listing_type'].map(listing_type_map)
train_data['shipping_logistic_type'] = train_data['shipping_logistic_type'].map(shipping_logistic_type_map)
train_data['shipping_payment'] = train_data['shipping_payment'].map(shipping_payment_map)
train_data
# Out:
#            sku        date  sold_quantity  current_price  currency  \
# sku
# 464801  464801  2021-02-01              0         156.78         0
# 464801  464801  2021-02-02              0         156.78         0
# 464801  464801  2021-02-03              0         156.78         0
# 464801  464801  2021-02-04              0         156.78         0
# 464801  464801  2021-02-05              1         156.78         0
# ...        ...         ...            ...            ...       ...
# 129187  129187  2021-03-31              0       22057.00         2
# 6707      6707  2021-03-31              0       26999.00         2
# 170355  170355  2021-03-31              0        3400.00         2
# 246568  246568  2021-03-31              0        6289.00         2
# 49718    49718  2021-03-31              0        1990.00         2
#
#         listing_type  shipping_logistic_type  shipping_payment  minutes_active
# sku
# 464801             0                       0                 1     1440.000000
# 464801             0                       0                 1     1440.000000
# 464801             0                       0                 1     1440.000000
# 464801             0                       0                 1     1440.000000
# 464801             0                       0                 1     1440.000000
# ...              ...                     ...               ...             ...
# 129187             0                       1                 1      267.710767
# 6707               0                       2                 1      266.083333
# 170355             0                       1                 0        0.252633
# 246568             0                       0                 1      135.416667
# 49718              0                       1                 0       88.033333
#
# [37660279 rows x 9 columns]

# %% [markdown]
# Add date features.

# %%
from datetime import datetime

start_date = datetime(2021, 2, 1)
unique_dates = train_data['date'].unique().tolist()
dates_dict = {x: (datetime.strptime(x, '%Y-%m-%d') - start_date).days for x in unique_dates}
train_data['day_index'] = train_data['date'].apply(lambda x: dates_dict[x])


holidays = {
    'REA': ['2021-04-01', '2021-04-02', '2021-04-21'],
    'ARG': ['2021-02-15', '2021-02-16', '2021-03-24', '2021-04-01', '2021-04-02'],
    'MXN': ['2021-02-01', '2021-03-15', '2021-04-01', '2021-04-02'],
    'DOL': []
}

train_data['is_holiday'] = train_data.apply(lambda x: 1 if x['date'] in holidays[x['currency']] else 0, axis=0)
train_data['date'] = pd.to_datetime(train_data['date'])

# 0 = Monday and 6 = Sunday
train_data['day_of_week'] = train_data['date'].apply(lambda x: x.dayofweek)
train_data['day_of_month'] = train_data['date'].apply(lambda x: x.day)

train_data
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-5719fc4c4af6> in <module>
#      14 }
#      15
# ---> 16 train_data['is_holiday'] = train_data.apply(lambda x: 1 if x['date'] in holidays[x['currency']] else 0, axis=0)
#      17 train_data['date'] = pd.to_datetime(train_data['date'])
#      18
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     282         ):
#     283
# --> 284             values = self.values
#     285             index = self.obj._get_axis(self.axis)
#     286             labels = self.agg_axis
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in values(self)
#     132     @cache_readonly
#     133     def values(self):
# --> 134         return self.obj.values
#     135
#     136     @cache_readonly
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in values(self)
#    5485         """
#    5486         self._consolidate_inplace()
# -> 5487         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    5488
#    5489     @property
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in as_array(self, transpose, items)
#     828             arr = np.asarray(mgr.blocks[0].get_values())
#     829         else:
# --> 830             arr = mgr._interleave()
#     831
#     832         return arr.transpose() if transpose else arr
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _interleave(self)
#     846             dtype = "object"
#     847
# --> 848         result = np.empty(self.shape, dtype=dtype)
#     849
#     850         itemmask = np.zeros(self.shape[0])
#
# MemoryError: Unable to allocate 2.81 GiB for an array with shape (10, 37660279) and data type object

# %% [markdown]
# Load additional data, specific from the items.

# %%
from collections import defaultdict
import json

item_details = defaultdict(lambda: None)
domain_map = defaultdict(lambda: None)

with open('inputs/items_static_metadata_full.jl') as f:
    for index, line in enumerate(f):
        data = json.loads(line)
        sku = data['sku']
        item_details[sku] = {
            'item_id': data['item_id'],
            'domain_id': domain_map.setdefault(data['item_domain_id'], len(domain_map))
        }

# %% [markdown]
# I get the list of unique items in the dataset

# %%
skus = train_data['sku'].unique().tolist()

for index, sku in enumerate(skus):
    pass
