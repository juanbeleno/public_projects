# %% [markdown]
# # Dataset
#
# In this Notebook, I'll extract some features to try to create an initial dataset for training a good model.

# %%
import pandas as pd

train_data = pd.read_parquet('inputs/train_data.parquet', engine='pyarrow')
train_data.index = train_data.sku
train_data
# Out:
#              sku        date  sold_quantity  current_price currency  \
# 0         464801  2021-02-01              0         156.78      REA
# 1         464801  2021-02-02              0         156.78      REA
# 2         464801  2021-02-03              0         156.78      REA
# 3         464801  2021-02-04              0         156.78      REA
# 4         464801  2021-02-05              1         156.78      REA
# ...          ...         ...            ...            ...      ...
# 37660274  129187  2021-03-31              0       22057.00      ARG
# 37660275    6707  2021-03-31              0       26999.00      ARG
# 37660276  170355  2021-03-31              0        3400.00      ARG
# 37660277  246568  2021-03-31              0        6289.00      ARG
# 37660278   49718  2021-03-31              0        1990.00      ARG
#
#          listing_type shipping_logistic_type shipping_payment  minutes_active
# 0             classic            fulfillment    free_shipping     1440.000000
# 1             classic            fulfillment    free_shipping     1440.000000
# 2             classic            fulfillment    free_shipping     1440.000000
# 3             classic            fulfillment    free_shipping     1440.000000
# 4             classic            fulfillment    free_shipping     1440.000000
# ...               ...                    ...              ...             ...
# 37660274      classic               drop_off    free_shipping      267.710767
# 37660275      classic          cross_docking    free_shipping      266.083333
# 37660276      classic               drop_off    paid_shipping        0.252633
# 37660277      classic            fulfillment    free_shipping      135.416667
# 37660278      classic               drop_off    paid_shipping       88.033333
#
# [37660279 rows x 9 columns]

# %% [markdown]
# I'll manually define mappings from categorical variables to numbers.

# %%
currency_map = {
    'REA': 0,
    'MEX': 1,
    'ARG': 2,
    'DOL': 3
}

listing_type_map = {
    'classic': 0,
    'premium': 1
}

shipping_logistic_type_map = {
    'fulfillment': 0,
    'drop_off': 1,
    'cross_docking': 2
}

shipping_payment_map = {
    'paid_shipping': 0,
    'free_shipping': 1
}

# %% [markdown]
# I'll replace the values of the categorical variables with their equivalent in numbers.

# %%
train_data['currency'] = train_data['currency'].map(currency_map)
train_data['listing_type'] = train_data['listing_type'].map(listing_type_map)
train_data['shipping_logistic_type'] = train_data['shipping_logistic_type'].map(shipping_logistic_type_map)
train_data['shipping_payment'] = train_data['shipping_payment'].map(shipping_payment_map)
train_data
# Out:
#              sku        date  sold_quantity  current_price  currency  \
# 0         464801  2021-02-01              0         156.78         0
# 1         464801  2021-02-02              0         156.78         0
# 2         464801  2021-02-03              0         156.78         0
# 3         464801  2021-02-04              0         156.78         0
# 4         464801  2021-02-05              1         156.78         0
# ...          ...         ...            ...            ...       ...
# 37660274  129187  2021-03-31              0       22057.00         2
# 37660275    6707  2021-03-31              0       26999.00         2
# 37660276  170355  2021-03-31              0        3400.00         2
# 37660277  246568  2021-03-31              0        6289.00         2
# 37660278   49718  2021-03-31              0        1990.00         2
#
#           listing_type  shipping_logistic_type  shipping_payment  \
# 0                    0                       0                 1
# 1                    0                       0                 1
# 2                    0                       0                 1
# 3                    0                       0                 1
# 4                    0                       0                 1
# ...                ...                     ...               ...
# 37660274             0                       1                 1
# 37660275             0                       2                 1
# 37660276             0                       1                 0
# 37660277             0                       0                 1
# 37660278             0                       1                 0
#
#           minutes_active
# 0            1440.000000
# 1            1440.000000
# 2            1440.000000
# 3            1440.000000
# 4            1440.000000
# ...                  ...
# 37660274      267.710767
# 37660275      266.083333
# 37660276        0.252633
# 37660277      135.416667
# 37660278       88.033333
#
# [37660279 rows x 9 columns]

# %% [markdown]
# Add date features.

# %%
from datetime import datetime

start_date = datetime(2021, 2, 1)
unique_dates = train_data['date'].unique().tolist()
dates_dict = {x: (datetime.strptime(x, '%Y-%m-%d') - start_date).days for x in unique_dates}
train_data['day_index'] = train_data['date'].apply(lambda x: dates_dict[x])


holidays = {
    'REA': ['2021-04-01', '2021-04-02', '2021-04-21'],
    'ARG': ['2021-02-15', '2021-02-16', '2021-03-24', '2021-04-01', '2021-04-02'],
    'MXN': ['2021-02-01', '2021-03-15', '2021-04-01', '2021-04-02'],
    'DOL': []
}

train_data['is_holiday'] = train_data.apply(lambda x: 1 if x['date'] in holidays[x['currency']] else 0)
train_data['date'] = pd.to_datetime(train_data['date'])

# 0 = Monday and 6 = Sunday
train_data['day_of_week'] = train_data['date'].apply(lambda x: x.dayofweek)
train_data['day_of_month'] = train_data['date'].apply(lambda x: x.day)

train_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3207118cd7df> in <module>
#       3 start_date = datetime(2021, 2, 1)
#       4 unique_dates = train_data['date'].unique().tolist()
# ----> 5 dates_dict = {x: (datetime.strptime(x, '%Y-%m-%d') - start_date).days for x in unique_dates}
#       6 train_data['day_index'] = train_data['date'].apply(lambda x: dates_dict[x])
#       7
#
# <ipython-input-5-3207118cd7df> in <dictcomp>(.0)
#       3 start_date = datetime(2021, 2, 1)
#       4 unique_dates = train_data['date'].unique().tolist()
# ----> 5 dates_dict = {x: (datetime.strptime(x, '%Y-%m-%d') - start_date).days for x in unique_dates}
#       6 train_data['day_index'] = train_data['date'].apply(lambda x: dates_dict[x])
#       7
#
# TypeError: strptime() argument 1 must be str, not int

# %% [markdown]
# Load additional data, specific from the items.

# %%
from collections import defaultdict
import json

item_details = defaultdict(lambda: None)
domain_map = defaultdict(lambda: None)

with open('inputs/items_static_metadata_full.jl') as f:
    for index, line in enumerate(f):
        data = json.loads(line)
        sku = data['sku']
        item_details[sku] = {
            'item_id': data['item_id'],
            'domain_id': domain_map.setdefault(data['item_domain_id'], len(domain_map))
        }

# %% [markdown]
# I get the list of unique items in the dataset

# %%
skus = train_data['sku'].unique().tolist()

for index, sku in enumerate(skus):
    pass
